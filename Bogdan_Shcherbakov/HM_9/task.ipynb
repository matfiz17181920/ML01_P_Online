# %% [markdown]
# Для любых видео восстановить траекторию движения (t вектор). Выполнить визуализацию.
# Определить параметры, которые влияют на "точность" определения вектора t
# Использовать решение на базе нейронных сетей.
# Любые идеи.
#
# ***slam прикрутить.
# Видео 1 но что бы работало.
#
# ### Задача:
# - Построить траекторию движения и направления поворота камеры по видео с камеры.
#
# ### Решение:
# - Искал ключевые точки с помощью SIFT и фильтровал их с помощью FLANN и RANSAC
# - Вычислял EssentialMat и восстанавливал положения и ориентацию камеры
#
# ### Выводы:
# - Сложно, долго и не точно.
# - Хотел считать in real time с камеры телефона, получилось передать оптический поток, но не получилось спарсить данные датчиков гироскопа и акселерометра, буду еще пробовать. В идеале может получиться брать изображение сразу с двух камер.
# - Хотел попробовать MIDAS для определения глубины изображения, тоже не вышло, буду пробовать.
# - SLAM прикрутить не пробовал, но очень хочется
# - Почитал и попробовал что то, результатов практически нет, решил хотя бы что то оформить.
#
# ### Вывод программы:
# ![test.png](attachment:test.png)
# ![test2.png](attachment:test2.png)
# Ссылка на видео https://drive.google.com/drive/folders/1ZeJ8PBq1rr761l87azqZhib11ptCTgO7?usp=sharing
